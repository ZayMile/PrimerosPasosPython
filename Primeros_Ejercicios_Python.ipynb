# %% [markdown]
# <a href="https://colab.research.google.com/github/ZayMile/PrimerosPasosPython/blob/main/Primeros_Ejercicios_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Ejercicio
#
# Escribir un programa que pregunte el nombre del usuario en consola y despues de que el usuario lo introduzca muestre por pantalla la cadena ¡Hola *'nombre'*!
# *'nombre'.* es el nombre que el usuario haya introducido.

# %%
# Solución
nombre = input('Ingrese su nombre: ')
print(f'Hola {nombre}')
# Out:
# Ingrese su nombre: Zayra
# Hola Zayra

# %% [markdown]
# # 2. Ejercicio
#
#
#
# ![imagen.png](data:image/png;base64,...)

# %%
# Solución
resultado = ((3+2)/(2-5))**2
print(f'El resultado de la operación es: {resultado}')
# Out:
# El resultado de la operación es: 2.777777777777778

# %% [markdown]
# # 3. Ejercicio
# ![imagen.png](data:image/png;base64,...)

# %%
# Solución
horas = int(input('Ingrese el número de horas trabajadas '))
costo = float(input('Ingrese el coso por hora '))
pago = horas * costo
print(f'El pago que le corresponde es: {pago}')
# Out:
# Ingrese el número de horas trabajadas 2
# Ingrese el coso por hora 1000
# El pago que le corresponde es: 2000.0

# %% [markdown]
# # 4. Ejercicio
# ![imagen.png](data:image/png;base64,...)

# %%
# Solución
n = int(input('Ingrese un entero '))
suma = (n*(n+1))/2
print(f'La suma es: {suma}')
# Out:
# Ingrese un entero 2
# La suma es: 3.0
